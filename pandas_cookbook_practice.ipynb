# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/gigabyte/notebook/pandasenv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install numpy
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/gigabyte/notebook/pandasenv/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('college.csv')

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
data.shape
# Out:
# (7535, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INSTNM              7535 non-null   object
#  1   CITY                7535 non-null   object
#  2   STABBR              7535 non-null   object
#  3   HBCU                7164 non-null   float64
#  4   MENONLY             7164 non-null   float64
#  5   WOMENONLY           7164 non-null   float64
#  6   RELAFFIL            7535 non-null   int64
#  7   SATVRMID            1185 non-null   float64
#  8   SATMTMID            1196 non-null   float64
#  9   DISTANCEONLY        7164 non-null   float64
#  10  UGDS                6874 non-null   float64
#  11  UGDS_WHITE          6874 non-null   float64
#  12  UGDS_BLACK          6874 non-null   float64
#  13  UGDS_HISP           6874 non-null   float64
#  14  UGDS_ASIAN          6874 non-null   float64
# ...

# %%
data.describe().T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
data.describe(include = [np.object, pd.Categorical]).T
# Out:
# /tmp/ipykernel_5596/3152733340.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.describe(include = [np.object, pd.Categorical]).T
#                    count unique                       top  freq
# INSTNM              7535   7535  Alabama A & M University     1
# CITY                7535   2514                  New York    87
# STABBR              7535     59                        CA   773
# MD_EARN_WNE_P10     6413    598         PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038         PrivacySuppressed  1510

# %%
data_dict = pd.read_csv('college_data_dictionary.csv')

# %%
data_dict
# Out:
#            column_name                                        description
# 0               INSTNM                                   Institution Name
# 1                 CITY                                      City Location
# 2               STABBR                                 State Abbreviation
# 3                 HBCU           Historically Black College or University
# 4              MENONLY                                       0/1 Men Only
# 5            WOMENONLY                                     0/1 Women only
# 6             RELAFFIL                          0/1 Religious Affiliation
# 7             SATVRMID                                  SAT Verbal Median
# 8             SATMTMID                                    SAT Math Median
# 9         DISTANCEONLY                            Distance Education Only
# 10                UGDS                           Undergraduate Enrollment
# 11          UGDS_WHITE                            Percent Undergrad White
# ...

# %%
different_cols = ['RELAFFIL', 'SATMTMID', 'CURROPER', 'INSTNM', 'STABBR']
col2 = data.loc[:, different_cols]
col2.head()
# Out:
#    RELAFFIL  SATMTMID  CURROPER                               INSTNM STABBR
# 0         0     420.0         1             Alabama A & M University     AL
# 1         0     565.0         1  University of Alabama at Birmingham     AL
# 2         1       NaN         1                   Amridge University     AL
# 3         0     590.0         1  University of Alabama in Huntsville     AL
# 4         0     430.0         1             Alabama State University     AL

# %% [markdown]
# <b><font size = '5'><font color = 'blue'>CHANGING THE COLUMN DATATYPES <b></font></color>

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
memory_usage = col2.memory_usage(deep = True)         #deep parameter is used to EXTRACT THE EXACT AMOUNT OF MEMORY
memory_usage                                          #FROM THE OBJECT TYPE
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %% [markdown]
# <b> RELAFFIL --> 0/1 and uses 64-bit int which consumes a lot of memory. Lets change it to 8-bit int. <b>
#     <b> Same goes for CURROPER <b>

# %%
col2['RELAFFIL'] = col2['RELAFFIL'].astype(np.int8)

# %%
col2.dtypes
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
org_mem = col2.memory_usage(deep = True)

# %%
org_mem     #look how much memory is used now
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
#now lets try to change the object types to categorical.

#you can change object to categorical if they have low cardinality (no. of unique values)


#uniques value of STABBR is very low so lets try to change the column type to Categorical

col2.select_dtypes(include = ['object']).nunique()
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
col2['STABBR'] = col2['STABBR'].astype('category')

# %%
col2.dtypes
# Out:
# RELAFFIL        int8
# SATMTMID     float64
# CURROPER       int64
# INSTNM        object
# STABBR      category
# dtype: object

# %%
new_mem = col2.memory_usage(deep = True)

# %%
new_mem
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660699
# STABBR       13120
# dtype: int64

# %%
data_mov = pd.read_csv('movie.csv')

# %%
data_mov.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
data_mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
data_mov.set_index(['movie_title'])
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %% [markdown]
# <b><font size = '5'><font color = 'blue'> BASIC ANALYSIS <b></font>

# %%
data_mov.describe(include = [np.number]).T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
#Find the five lowest budget movies from the top 100 scoring movies by
#taking advantage of the convenience methods, nlargest and nsmallest .



movie2 = data_mov[['movie_title', 'imdb_score', 'budget']]
movie2.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
movie2.nlargest(100, 'imdb_score').head()
# Out:
#                    movie_title  imdb_score      budget
# 2725          Towering Inferno         9.5         NaN
# 1920  The Shawshank Redemption         9.3  25000000.0
# 3402             The Godfather         9.2   6000000.0
# 2779                   Dekalog         9.1         NaN
# 4312      Kickboxer: Vengeance         9.1  17000000.0

# %%
movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget').head()
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
#Selecting the largest of each group by sorting
movie2 = data_mov[['title_year', 'movie_title', 'imdb_score']]
movie2.sort_values('title_year', ascending = False).head()

#only the year column is sorted. What if we need to sort
# title_year and imdb_score
# Out:
#       title_year                   movie_title  imdb_score
# 3884      2016.0                      The Veil         4.7
# 2375      2016.0    My Big Fat Greek Wedding 2         6.1
# 2794      2016.0          Miracles from Heaven         6.8
# 92        2016.0  Independence Day: Resurgence         5.5
# 153       2016.0               Kung Fu Panda 3         7.2

# %%
movie3 = movie2.sort_values(['title_year', 'imdb_score'], ascending = False).head()

# %%
movie3.head()
# Out:
#       title_year                  movie_title  imdb_score
# 4312      2016.0         Kickboxer: Vengeance         9.1
# 4277      2016.0  A Beginner's Guide to Snuff         8.7
# 3798      2016.0                      Airlift         8.5
# 27        2016.0   Captain America: Civil War         8.2
# 98        2016.0          Godzilla Resurgence         8.2

# %%
#but we only need the top value for each year

movie_top_year = movie3.drop_duplicates(subset = 'title_year')
movie_top_year.head()
# Out:
#       title_year           movie_title  imdb_score
# 4312      2016.0  Kickboxer: Vengeance         9.1

# %%
movie2 = data_mov[['movie_title', 'imdb_score', 'budget']]
movie_smallest_largest = movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')

# %%
movie_smallest_largest
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
city = data['CITY']

# %% [markdown]
# <b><font size = '5'><font color = 'blue'> INDEXING THROUGH COLUMNS (iloc & .loc) <b></font>

# %%
city.iloc[4 : 50 : 10]      #4 to 50 with interval of 10
# Out:
# 4     Montgomery
# 14    Enterprise
# 24      Florence
# 34        Marion
# 44     Evergreen
# Name: CITY, dtype: object

# %%
city.loc['Heritage Christian University']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [84], in <module>
# ----> 1 city.loc['Heritage Christian University']
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
# ...

# %%
#Slicing the data and selecting specifics

data.iloc[:3, :4]       #rows, columns
# Out:
#                                 INSTNM        CITY STABBR  HBCU
# 0             Alabama A & M University      Normal     AL   1.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0
# 2                   Amridge University  Montgomery     AL   0.0

# %%
data.iloc[:, [4,6]].head()      #all rows, 4,6 columns
# Out:
#    MENONLY  RELAFFIL
# 0      0.0         0
# 1      0.0         0
# 2      0.0         1
# 3      0.0         0
# 4      0.0         0

# %%
first_ten = data.index[:10]
data.loc[first_ten, ['CITY', 'STABBR']]
# Out:
#              CITY STABBR
# 0          Normal     AL
# 1      Birmingham     AL
# 2      Montgomery     AL
# 3      Huntsville     AL
# 4      Montgomery     AL
# 5      Tuscaloosa     AL
# 6  Alexander City     AL
# 7          Athens     AL
# 8      Montgomery     AL
# 9          Auburn     AL

# %%
data.iloc[[100,200], [7,15]]      #100,200 --> rows : 7,15 --> columns
# Out:
#      SATVRMID  UGDS_AIAN
# 100       NaN     0.0451
# 200       NaN        NaN

# %%
data.iloc[5 , -4]       #singular value of 5row and -4columnn
# Out:
# 0.401

# %%
data.iloc[90:80:2, 5]
# Out:
# Series([], Name: WOMENONLY, dtype: float64)

# %% [markdown]
# <b><font size = '5'><font color = 'blue'> BOOLEAN INDEXING <b></font>

# %%
movie = pd.read_csv('movie.csv', index_col = 'movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
duration_120 = movie['duration'] > 120

# %%
print(duration_120.value_counts(normalize = True))
print('\n')
print(duration_120.value_counts())
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64
#
#
# False    3877
# True     1039
# Name: duration, dtype: int64

# %%
print(duration_120.sum())
print(duration_120.mean())
# Out:
# 1039
# 0.2113506916192026

# %%
movie['duration'].dropna().gt(120).mean()       #gt --> greater then
# Out:
# 0.21199755152009794

# %%
#applying multiple operations

movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
cr1 = movie.imdb_score > 8
cr2 = movie.content_rating == 'PG-13'
cr3 = ((movie.title_year < 2000) | (movie.title_year > 2009))

# %%
cr_final = cr1 & cr2 & cr3

# %%
cr_final.isnull().sum()
# Out:
# 0

# %%
cr_final.value_counts(normalize = True)
# Out:
# False    0.995321
# True     0.004679
# dtype: float64

# %%
cr4 = movie.imdb_score < 5
cr5 = movie.content_rating == 'R'
cr6 = ((movie.title_year >= 2000) | (movie.title_year <= 2010))

# %%
## alternate version of the above code

final_crit_alternate = (movie.imdb_score < 5) & \
                        (movie.content_rating == 'R') & \
                        ((movie.title_year >= 2000) | (movie.title_year <= 2010))

# %%
cr_final2 = cr4 & cr5 & cr6

# %%
cr_final2.isnull().sum()
# Out:
# 0

# %%
cr_final2.value_counts(normalize = True)
# Out:
# False    0.970504
# True     0.029496
# dtype: float64

# %%
final_cr = cr_final | cr_final2

# %%
final_cr.value_counts(normalize = True)
# Out:
# False    0.965826
# True     0.034174
# dtype: float64

# %%
cols = ['imdb_score', 'content_rating', 'title_year']

movie_filtered = movie.loc[:, cols]

movie_filtered.sort_values('imdb_score', ascending = False)
# Out:
#                                 imdb_score content_rating  title_year
# movie_title
# Towering Inferno                       9.5            NaN         NaN
# The Shawshank Redemption               9.3              R      1994.0
# The Godfather                          9.2              R      1972.0
# Dekalog                                9.1          TV-MA         NaN
# Kickboxer: Vengeance                   9.1            NaN      2016.0
# ...                                    ...            ...         ...
# Superbabies: Baby Geniuses 2           1.9             PG      2004.0
# Disaster Movie                         1.9          PG-13      2008.0
# The Helix... Loaded                    1.9              R      2005.0
# Foodfight!                             1.7             PG      2012.0
# Justin Bieber: Never Say Never         1.6              G      2011.0
#
# [4916 rows x 3 columns]

# %%
data[data['STABBR'] == 'TX'].head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 3610        0.0         1     530.0     545.0           0.0  ...     0.0454
# 3611        0.0         0       NaN       NaN           0.0  ...     0.0002
# 3612        0.0         0       NaN       NaN           0.0  ...     0.0000
# 3613        0.0         0       NaN       NaN           0.0  ...     0.0264
# 3614        0.0         0     475.0     490.0           0.0  ...     0.0285
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
#Alternate version

data2 = data.set_index('STABBR')           #--> you can apply loc only on index columns
data2.loc['TX']
# Out:
#                                          INSTNM         CITY  HBCU  MENONLY  \
# STABBR
# TX                 Abilene Christian University      Abilene   0.0      0.0
# TX                      Alvin Community College        Alvin   0.0      0.0
# TX                             Amarillo College     Amarillo   0.0      0.0
# TX                             Angelina College       Lufkin   0.0      0.0
# TX                      Angelo State University   San Angelo   0.0      0.0
# ...                                         ...          ...   ...      ...
# TX              Strayer University-North Dallas       Dallas   NaN      NaN
# TX               Strayer University-San Antonio  San Antonio   NaN      NaN
# TX                  Strayer University-Stafford     Stafford   NaN      NaN
# TX                              Vantage College      El Paso   NaN      NaN
# TX      Excel Learning Center-San Antonio South  San Antonio   NaN      NaN
#
# ...

# %%
#Selecting multiple states

states = ['TX', 'NY', 'CA']
data[data['STABBR'].isin(states)].head(10)
# Out:
#                                              INSTNM              CITY STABBR  \
# 192                       Academy of Art University     San Francisco     CA
# 193          ITT Technical Institute-Rancho Cordova    Rancho Cordova     CA
# 194  Academy of Chinese Culture and Health Sciences           Oakland     CA
# 195        The Academy of Radio and TV Broadcasting  Huntington Beach     CA
# 196            Avalon School of Cosmetology-Alameda           Alameda     CA
# 197                              College of Alameda           Alameda     CA
# 198                           Allan Hancock College       Santa Maria     CA
# 199   American Academy of Dramatic Arts-Los Angeles       Los Angeles     CA
# 200           American Baptist Seminary of the West          Berkeley     CA
# 201            American Film Institute Conservatory       Los Angeles     CA
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# ...

# %%
college2 = data.set_index('STABBR')
college2.index.is_monotonic_increasing
# Out:
# False

# %%
college3 = college2.sort_index()
college3.index.is_monotonic_increasing
# Out:
# True

# %%
# %timeit college3.loc['TX']
# Out:
# 36.6 µs ± 405 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 225 µs ± 8.38 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# <b> Gaining Persepective on Stock Prices <b>

# %%
stock_data = pd.read_csv('slb_stock.csv', index_col = 'Date', parse_dates = ['Date'])

# %%
stock_data.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
stock_data.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
slb_close = stock_data['Close']

# %%
slb_summary = slb_close.describe(percentiles = [.1, .9])

# %%
crt = ((slb_close < slb_summary.loc['90%']) | (slb_close > slb_summary.loc['10%']))

# %%
upper_10 = slb_summary.loc['90%']
lower_10 = slb_summary.loc['10%']
criteria = (slb_close < lower_10) | (slb_close > upper_10)
slb_top_bottom_10 = slb_close[criteria]

# %%
slb_bottom_10 = slb_close[crt]

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/gigabyte/notebook/pandasenv/bin/python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
slb_close.plot(color='black', figsize=(12,6))
slb_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')
xmin = criteria.index[0]
xmax = criteria.index[-1]
plt.hlines(y=[lower_10, upper_10], xmin=xmin,xmax=xmax, color='black')

# %% [markdown]
# <b> DEMO: SQL like operation <b>

# %%
#Find all the female employees that work in the police or fire
#departments that have a base salary between 80 and 120 thousand dollars.

employee = pd.read_csv('employee.csv')

# %%
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
employee.dtypes
# Out:
# UNIQUE_ID              int64
# POSITION_TITLE        object
# DEPARTMENT            object
# BASE_SALARY          float64
# RACE                  object
# EMPLOYMENT_TYPE       object
# GENDER                object
# EMPLOYMENT_STATUS     object
# HIRE_DATE             object
# JOB_DATE              object
# dtype: object

# %%
employee.describe(include = [object, int, float ]).T
# Out:
#                     count unique                            top  freq  \
# UNIQUE_ID          2000.0    NaN                            NaN   NaN
# POSITION_TITLE       2000    330          SENIOR POLICE OFFICER   220
# DEPARTMENT           2000     24  Houston Police Department-HPD   638
# BASE_SALARY        1886.0    NaN                            NaN   NaN
# RACE                 1965      6      Black or African American   700
# EMPLOYMENT_TYPE      2000      5                      Full Time  1954
# GENDER               2000      2                           Male  1397
# EMPLOYMENT_STATUS    2000      2                         Active  1991
# HIRE_DATE            2000    999                     2016-03-28    11
# JOB_DATE             1997    947                     2002-01-05    34
#
#                            mean           std      min      25%      50%  \
# UNIQUE_ID                 999.5    577.494589      0.0   499.75    999.5
# ...

# %%
employee.isnull().sum()
# Out:
# UNIQUE_ID              0
# POSITION_TITLE         0
# DEPARTMENT             0
# BASE_SALARY          114
# RACE                  35
# EMPLOYMENT_TYPE        0
# GENDER                 0
# EMPLOYMENT_STATUS      0
# HIRE_DATE              0
# JOB_DATE               3
# dtype: int64

# %%
employee['DEPARTMENT'].value_counts()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Solid Waste Management             43
# Library                            36
# Fleet Management Department        36
# Admn. & Regulatory Affairs         29
# Municipal Courts Department        28
# Human Resources Dept.              24
# Houston Emergency Center (HEC)     23
# Housing and Community Devp.        22
# General Services Department        22
# Legal Department                   17
# Dept of Neighborhoods (DON)        17
# City Council                       11
# Finance                            10
# Houston Information Tech Svcs       9
# Planning & Development              7
# City Controller's Office            5
# Mayor's Office                      5
# Convention and Entertainment        1
# Name: DEPARTMENT, dtype: int64

# %%
depts = ['Houston Police Department-HPD', 'Houston Fire Department (HFD)']
criteria_dept = employee['DEPARTMENT'].isin(depts)
criteria_gender = employee['GENDER'] == 'Female'
cirteria_sal = ((employee['BASE_SALARY'] >= 80000) & employee['BASE_SALARY'] <= 120000)

# %%
final_crt = criteria_dept & criteria_gender & cirteria_sal

# %%
employee[final_crt].sort_index().sort_values('BASE_SALARY', ascending = False)
# Out:
#       UNIQUE_ID         POSITION_TITLE                     DEPARTMENT  \
# 1118       1118         POLICE CAPTAIN  Houston Police Department-HPD
# 595         595     STAFF PSYCHOLOGIST  Houston Police Department-HPD
# 61           61     IT PROJECT MANAGER  Houston Fire Department (HFD)
# 1519       1519      POLICE LIEUTENANT  Houston Police Department-HPD
# 474         474      POLICE LIEUTENANT  Houston Police Department-HPD
# ...         ...                    ...                            ...
# 1223       1223  SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1255       1255        POLICE SERGEANT  Houston Police Department-HPD
# 1288       1288  SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1413       1413  SENIOR POLICE OFFICER  Houston Police Department-HPD
# 1760       1760  SENIOR POLICE OFFICER  Houston Police Department-HPD
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# ...

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
fb_likes = movie['actor_1_facebook_likes'].dropna()

# %%
fb_likes.isnull().sum()
# Out:
# 0

# %%
fb_likes.describe(include = [.1, .25, .5, .75, .9]).astype(int)
# Out:
# count      4909
# mean       6494
# std       15106
# min           0
# 25%         607
# 50%         982
# 75%       11000
# max      640000
# Name: actor_1_facebook_likes, dtype: int64

# %%
fb_likes.hist()
# Out:
# <AxesSubplot:>

# %%
crt_high = fb_likes > 20000

# %%
crt_high.mean().round(2)
# Out:
# 0.08

# %%
fb_likes.where(crt_high).head()               #the output is not a dataframe
# Out:
# movie_title
# Avatar                                            NaN
# Pirates of the Caribbean: At World's End      40000.0
# Spectre                                           NaN
# The Dark Knight Rises                         27000.0
# Star Wars: Episode VII - The Force Awakens        NaN
# Name: actor_1_facebook_likes, dtype: float64

# %%
fb_likes.where(crt_high, other = 'null').head()
# Out:
# movie_title
# Avatar                                           null
# Pirates of the Caribbean: At World's End      40000.0
# Spectre                                          null
# The Dark Knight Rises                         27000.0
# Star Wars: Episode VII - The Force Awakens       null
# Name: actor_1_facebook_likes, dtype: object

# %%
#Alternate: 

fb_likes_cap2 = fb_likes.clip(lower = 3000, upper = 20000)

# %% [markdown]
# <b><font size = '5'><font color = 'blue'> GROUPING, AGGREGATION, FILTRATION & TRANSFORMATION <b></font>

# %%
flights = pd.read_csv('flights.csv')

# %%
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.groupby('AIRLINE').agg({'ARR_DELAY' : 'mean'})

#Alternate: 

# flights.groupby('AIRLINE')['ARR_DELAY'].agg('mean').head()
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# F9       13.630651
# HA        4.972973
# MQ        6.860591
# NK       18.436070
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353

# %%
#Finding the number of cancelled flights for every airline per weekday

flights.groupby(['AIRLINE', 'WEEKDAY']).agg({'CANCELLED': 'sum'})
# Out:
#                  CANCELLED
# AIRLINE WEEKDAY
# AA      1               41
#         2                9
#         3               16
#         4               20
#         5               18
# ...                    ...
# WN      3               18
#         4               10
#         5                7
#         6               10
#         7                7
#
# [98 rows x 1 columns]

# %%
#Finding the number and percentage of cancelled and diverted flights for every
#airline per weekday

#flights.groupby(['AIRLINE', 'WEEKDAY']).agg({'CANCELLED': 'sum','DIVERTED':'sum'}).head()   #cannot pass two ops

flights.groupby(['AIRLINE', 'WEEKDAY'])['CANCELLED', 'DIVERTED'].agg(['sum', 'mean']).head(10)
# Out:
# /tmp/ipykernel_5596/3551617979.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   flights.groupby(['AIRLINE', 'WEEKDAY'])['CANCELLED', 'DIVERTED'].agg(['sum', 'mean']).head(10)
#                 CANCELLED           DIVERTED
#                       sum      mean      sum      mean
# AIRLINE WEEKDAY
# AA      1              41  0.032106        6  0.004699
#         2               9  0.007341        2  0.001631
#         3              16  0.011949        2  0.001494
#         4              20  0.015004        5  0.003751
#         5              18  0.014151        1  0.000786
#         6              21  0.018667        9  0.008000
#         7              29  0.021837        1  0.000753
# AS      1               0  0.000000        0  0.000000
#         2               0  0.000000        0  0.000000
#         3               0  0.000000        0  0.000000

# %%
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
#For each origin and destination, finding the total number of flights, the number
#and percentage of cancelled flights, and the average and variance of the airtime


group_cols = ['ORG_AIR', 'DEST_AIR']
agg_cols = {'CANCELLED' : ['mean', 'sum', 'size'],
            'AIR_TIME': ['mean', 'var']}

flights.groupby(group_cols).agg(agg_cols).head(10)
# Out:
#                  CANCELLED             AIR_TIME
#                       mean sum size        mean        var
# ORG_AIR DEST_AIR
# ATL     ABE            0.0   0   31   96.387097  45.778495
#         ABQ            0.0   0   16  170.500000  87.866667
#         ABY            0.0   0   19   28.578947   6.590643
#         ACY            0.0   0    6   91.333333  11.466667
#         AEX            0.0   0   40   78.725000  47.332692
#         AGS            0.0   0   83   28.819277   9.393770
#         ALB            0.0   0   33  108.181818  41.903409
#         ANC            0.0   0    2  438.500000  40.500000
#         ASE            0.0   0    1  192.000000        NaN
#         ATW            0.0   0   10  106.400000  61.377778

# %%
#avg departure delay, avg distance for each month for each airline

group_cols = ['MONTH', 'AIRLINE']
agg_cols = {'DEP_DELAY': ['sum', 'mean'],
            'DIST' : ['sum', 'mean']}
df_flights_grp = flights.groupby(group_cols).agg(agg_cols)

# %%
# !pip install tabulate
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/gigabyte/notebook/pandasenv/bin/python -m pip install --upgrade pip' command.

# %%
pd.set_option('display.max_rows', None)
df_flights_grp
# Out:
#               DEP_DELAY                DIST
#                     sum       mean      sum         mean
# MONTH AIRLINE
# 1     AA         8460.0  12.645740   728748  1076.437223
#       AS          104.0   1.575758    68255  1034.166667
#       B6          309.0   6.717391    78150  1662.765957
#       DL         4721.0   5.715496   733393   876.216249
#       EV         5266.0   9.898496   261396   484.066667
#       F9         1497.0  14.821782    95506   918.326923
#       HA          -66.0  -3.882353    44342  2608.352941
#       MQ         6458.0  18.140449   153442   403.794737
#       NK         1870.0  15.454545   129984  1065.442623
#       OO         7240.0  13.021583   275594   481.807692
#       UA         9842.0  16.596965   718440  1189.470199
#       US          449.0   1.774704   293461  1137.445736
#       VX          391.0   4.600000    92341  1073.732558
#       WN         7611.0  11.159824   554370   799.956710
# ...

# %%
#find the total and average miles
#flown; and the maximum and minimum arrival delay for each airline for each
#weekday:

air_info = flights.groupby(['AIRLINE', 'WEEKDAY']).agg({'DIST' : ['sum', 'mean'], 'ARR_DELAY' : ['max', 'min']}).astype(int)

# %%
air_info.reset_index().head()
# Out:
#   AIRLINE  WEEKDAY  DIST_sum  DIST_mean  ARR_DELAY_max  ARR_DELAY_min
# 0      AA        1   1455386       1139            551            -60
# 1      AA        2   1358256       1107            725            -52
# 2      AA        3   1496665       1117            473            -45
# 3      AA        4   1452394       1089            349            -46
# 4      AA        5   1427749       1122            732            -41

# %%
#Changing the columns structure

lvl_0 = air_info.columns.get_level_values(0)
lvl_1 = air_info.columns.get_level_values(1)
air_info.columns = lvl_0 + '_' + lvl_1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [200], in <module>
#       1 #Changing the columns structure
#       3 lvl_0 = air_info.columns.get_level_values(0)
# ----> 4 lvl_1 = air_info.columns.get_level_values(1)
#       5 air_info.columns = lvl_0 + '_' + lvl_1
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/indexes/base.py:2008, in Index._get_level_values(self, level)
#    1972 def _get_level_values(self, level) -> Index:
#    1973     """
#    1974     Return an Index of values for requested level.
#    1975
#    (...)
#    2006     Index(['a', 'b', 'c'], dtype='object')
#    2007     """
# -> 2008     self._validate_index_level(level)
#    2009     return self
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/indexes/base.py:1927, in Index._validate_index_level(self, level)
#    1922         raise IndexError(
# ...

# %%
data.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY     UGDS  UGDS_WHITE  \
# 0        0.0         0     424.0     420.0           0.0   4206.0      0.0333
# 1        0.0         0     570.0     565.0           0.0  11383.0      0.5922
# 2        0.0         1       NaN       NaN           1.0    291.0      0.2990
# 3        0.0         0     595.0     590.0           0.0   5451.0      0.6988
# 4        0.0         0     425.0     430.0           0.0   4811.0      0.0158
#
# ...

# %%
"""
use the college dataset to calculate the mean and standard deviation of the
undergraduate student population per state. We then use this information to find the
maximum number of standard deviations from the mean that any single population value
is per state.
"""

data.groupby(['STABBR']).agg({'UGDS': ['mean', 'std']}).round(2)
# Out:
#            UGDS
#            mean       std
# STABBR
# AK      2493.20   4051.73
# AL      2789.87   4657.88
# AR      1644.15   3142.77
# AS      1276.00       NaN
# AZ      4130.47  14893.64
# CA      3518.31   6708.57
# CO      2324.88   4670.29
# CT      1873.55   2871.30
# DC      2645.28   3224.81
# DE      2491.05   4503.37
# FL      2492.86   7033.41
# FM      2344.00       NaN
# GA      2642.57   4422.13
# GU      1894.00   1773.85
# HI      2360.71   2999.33
# IA      2293.94   5815.22
# ID      2096.25   4864.68
# IL      2189.11   4079.63
# IN      2653.56   8278.00
# KS      1861.26   3672.76
# KY      1991.04   3783.43
# LA      1660.24   3484.83
# MA      2023.09   3267.42
# MD      3003.13   5836.88
# ME      1436.59   1808.41
# MH      1078.00       NaN
# MI      2643.02   5356.33
# MN      2085.95   3579.82
# MO      1557.06   3569.10
# MP      1120.00       NaN
# MS      2498.59   3847.65
# MT      1470.67   3006.73
# NC      2446.85   4212.35
# ...

# %%
def max_deviation(s):
    std_score = (s - s.mean()) / s.std()
    
    return std_score.abs().max()

# %%
data.groupby(['STABBR'])['UGDS'].agg(max_deviation).round(2)
# Out:
# STABBR
# AK     2.56
# AL     5.81
# AR     6.29
# AS      NaN
# AZ     9.90
# CA     6.15
# CO     5.04
# CT     5.62
# DC     2.41
# DE     3.49
# FL     8.39
# FM      NaN
# GA     5.45
# GU     1.03
# HI     3.77
# IA     6.54
# ID     4.47
# IL     7.28
# IN     9.06
# KS     4.86
# KY     5.22
# LA     6.54
# MA     6.07
# MD     5.29
# ME     4.01
# MH      NaN
# MI     6.67
# MN     7.84
# MO     7.21
# MP      NaN
# MS     3.98
# MT     3.87
# NC     4.86
# ND     3.53
# NE     5.04
# NH     5.33
# NJ     7.09
# NM     4.49
# NV     4.70
# NY     8.16
# OH    10.28
# OK     5.88
# OR     5.32
# PA    10.09
# PR     5.98
# PW      NaN
# RI     2.89
# SC     5.97
# SD     4.18
# TN     6.05
# TX     7.73
# UT     5.15
# VA     6.95
# VI      NaN
# VT     3.85
# WA     6.60
# WI     5.77
# WV     7.25
# WY     2.79
# Name: UGDS, dtype: float64

# %%
max_deviation.__name__ = 'Max Deviation'

data.groupby(['STABBR', 'RELAFFIL'])['UGDS', 'SATVRMID', 'SATMTMID'].agg([max_deviation, 'mean', 'std']).head()
# Out:
# /tmp/ipykernel_5596/4247196314.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['STABBR', 'RELAFFIL'])['UGDS', 'SATVRMID', 'SATMTMID'].agg([max_deviation, 'mean', 'std']).head()
#                          UGDS                                SATVRMID  \
#                 Max Deviation         mean          std Max Deviation
# STABBR RELAFFIL
# AK     0             2.061043  3508.857143  4539.517868           NaN
#        1             1.140888   123.333333   132.937329           NaN
# AL     0             5.213676  3248.774648  5102.393025      1.610100
#        1             2.357878   979.722222   870.815899      1.470390
# AR     0             5.765238  1793.691176  3401.647776      1.949778
#
#                                             SATMTMID
#                        mean        std Max Deviation        mean        std
# STABBR RELAFFIL
# ...

# %%
def pct_btw_1_and_3k(s):
    return s.between(1000, 3000).mean()

# %%
data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_btw_1_and_3k).head(10)
# Out:
# STABBR  RELAFFIL
# AK      0           0.142857
#         1           0.000000
# AL      0           0.236111
#         1           0.333333
# AR      0           0.279412
#         1           0.111111
# AS      0           1.000000
# AZ      0           0.096774
#         1           0.000000
# CA      0           0.095238
# Name: UGDS, dtype: float64

# %%
#Altering the funtion

def pct_between(s, low, high):
    return s.between(low, high).mean()

# %%
data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, 10000).head(10)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# CA      0           0.201970
# Name: UGDS, dtype: float64

# %%
data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg([pct_between,1000,10000,'mean']).head()
# Out:
# /tmp/ipykernel_5596/3841603325.py:1: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the function.
#   data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg([pct_between,1000,10000,'mean']).head()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [223], in <module>
# ----> 1 data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg([pct_between,1000,10000,'mean']).head()
#
# File ~/notebook/pandasenv/lib/python3.8/site-packages/pandas/core/groupby/generic.py:271, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
# ...

# %%
#Using *args, **kwargs                                #Funtion Closure

def make_agg_func(func, name, *args, **kwargs):
    def wrapper(x):
        return func(x, *args, **kwargs)
    wrapper.__name__ = name
    return wrapper

# %%
my_agg1 = make_agg_func(pct_between, 'pct_btw_1_3k', 1000, 3000)
my_agg2 = make_agg_func(pct_between, 'pct_btw_1_10k', 1000, 10000)

# %%
data.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean',my_agg1, my_agg2]).round(2).head()
# Out:
#                     mean  pct_btw_1_3k  pct_btw_1_10k
# STABBR RELAFFIL
# AK     0         3508.86          0.14           0.43
#        1          123.33          0.00           0.00
# AL     0         3248.77          0.24           0.46
#        1          979.72          0.33           0.38
# AR     0         1793.69          0.28           0.40

# %%
data.query('STABBR == "FL"' and 'RELAFFIL == ')

# %%
grouped = data.groupby(['STABBR', 'RELAFFIL'])

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
print([attr for attr in dir(grouped) if not attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'ewm', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sample', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'value_counts', 'var']

# %%
grouped.ngroups
# Out:
# 112

# %%
grouped.get_group(('FL', 1)).head()
# Out:
#                                     INSTNM           CITY STABBR  HBCU  \
# 712         The Baptist College of Florida     Graceville     FL   0.0
# 713                       Barry University          Miami     FL   0.0
# 714  Gooding Institute of Nurse Anesthesia    Panama City     FL   0.0
# 715             Bethune-Cookman University  Daytona Beach     FL   1.0
# 724             Johnson University Florida      Kissimmee     FL   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# 712      0.0        0.0         1     545.0     465.0           0.0   454.0
# 713      0.0        0.0         1     470.0     462.0           0.0  3913.0
# 714      0.0        0.0         1       NaN       NaN           0.0     NaN
# 715      0.0        0.0         1     405.0     395.0           0.0  3897.0
# 724      0.0        0.0         1     480.0     470.0           0.0   220.0
#
#      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# ...

# %%
weight_loss = pd.read_csv('weight_loss.csv')

# %%
weight_loss
# Out:
#    Name Month    Week  Weight
# 0   Bob   Jan  Week 1     291
# 1   Amy   Jan  Week 1     197
# 2   Bob   Jan  Week 2     288
# 3   Amy   Jan  Week 2     189
# 4   Bob   Jan  Week 3     283
# 5   Amy   Jan  Week 3     189
# 6   Bob   Jan  Week 4     283
# 7   Amy   Jan  Week 4     190
# 8   Bob   Feb  Week 1     283
# 9   Amy   Feb  Week 1     190
# 10  Bob   Feb  Week 2     275
# 11  Amy   Feb  Week 2     184
# 12  Bob   Feb  Week 3     268
# 13  Amy   Feb  Week 3     177
# 14  Bob   Feb  Week 4     268
# 15  Amy   Feb  Week 4     173
# 16  Bob   Mar  Week 1     268
# 17  Amy   Mar  Week 1     173
# 18  Bob   Mar  Week 2     271
# 19  Amy   Mar  Week 2     173
# 20  Bob   Mar  Week 3     265
# 21  Amy   Mar  Week 3     170
# 22  Bob   Mar  Week 4     261
# 23  Amy   Mar  Week 4     170
# 24  Bob   Apr  Week 1     261
# 25  Amy   Apr  Week 1     170
# 26  Bob   Apr  Week 2     258
# 27  Amy   Apr  Week 2     164
# 28  Bob   Apr  Week 3     253
# 29  Amy   Apr  Week 3     164
# ...

# %%
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
def find_perc_loss(s):
    return (s - s.iloc[0])/ s.iloc[0]

# %%
bob_jan = weight_loss.query('Name == "Bob" and Month =="Jan"')
find_perc_loss(bob_jan['Weight'])
# Out:
# 0    0.000000
# 2   -0.010309
# 4   -0.027491
# 6   -0.027491
# Name: Weight, dtype: float64

# %%
pct_loss = weight_loss.groupby(['Name', 'Month'])['Weight'].transform(find_perc_loss)

# %%
pct_loss.head()
# Out:
# 0    0.000000
# 1    0.000000
# 2   -0.010309
# 3   -0.040609
# 4   -0.027491
# Name: Weight, dtype: float64

# %%
weight_loss['Perc Weight Loss'] = pct_loss.round(3)
weight_loss.query('Name=="Bob" and Month in ["Jan", "Feb"]')
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 0   Bob   Jan  Week 1     291             0.000
# 2   Bob   Jan  Week 2     288            -0.010
# 4   Bob   Jan  Week 3     283            -0.027
# 6   Bob   Jan  Week 4     283            -0.027
# 8   Bob   Feb  Week 1     283             0.000
# 10  Bob   Feb  Week 2     275            -0.028
# 12  Bob   Feb  Week 3     268            -0.053
# 14  Bob   Feb  Week 4     268            -0.053

# %%
week4 = weight_loss.query('Week == "Week 4"')

# %%
week4
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 6   Bob   Jan  Week 4     283            -0.027
# 7   Amy   Jan  Week 4     190            -0.036
# 14  Bob   Feb  Week 4     268            -0.053
# 15  Amy   Feb  Week 4     173            -0.089
# 22  Bob   Mar  Week 4     261            -0.026
# 23  Amy   Mar  Week 4     170            -0.017
# 30  Bob   Apr  Week 4     250            -0.042
# 31  Amy   Apr  Week 4     161            -0.053

# %%
winner = week4.pivot(index='Month', columns='Name',values='Perc Weight Loss')

# %%
winner
# Out:
# Name     Amy    Bob
# Month
# Apr   -0.053 -0.042
# Feb   -0.089 -0.053
# Jan   -0.036 -0.027
# Mar   -0.017 -0.026

# %% [markdown]
# <b><font size = '5'><font color = 'blue'> VISUALIZATION (MATPLOTLIB, PANDAS, SEABORN) <b></font>
